# %% [markdown]
# <a href="https://colab.research.google.com/github/ToniBrax/AI-whispers/blob/master/MusicGen_ClownOfMadness_plus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b plus https://github.com/ClownOfMadness/audiocraft_plus
# %cd /content/audiocraft_plus
# !pip install -r requirements.txt
# !python app.py --share
# Out:
# /content
# Cloning into 'audiocraft_plus'...
# remote: Enumerating objects: 1851, done.
# remote: Counting objects: 100% (381/381), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 1851 (delta 334), reused 328 (delta 328), pack-reused 1470 (from 1)
# Receiving objects: 100% (1851/1851), 1.60 MiB | 5.42 MiB/s, done.
# Resolving deltas: 100% (1130/1130), done.
# /content/audiocraft_plus
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 4.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.3 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
# ...
